# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic_passengers = pd.read_csv('train.csv', index_col='PassengerId')

# %%
titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
titanic_passengers.shape
# Out:
# (891, 11)

# %%
titanic_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic_passengers.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_passengers['Age'].hist()
# Out:
# <Axes: >

# %%
plt.hist(titanic_passengers['Age'], bins=14)
# Out:
# (array([ 47.,  21.,  45., 133., 118., 115.,  85.,  49.,  44.,  24.,  18.,
#           8.,   6.,   1.]),
#  array([ 0.42      ,  6.10428571, 11.78857143, 17.47285714, 23.15714286,
#         28.84142857, 34.52571429, 40.21      , 45.89428571, 51.57857143,
#         57.26285714, 62.94714286, 68.63142857, 74.31571429, 80.        ]),
#  <BarContainer object of 14 artists>)

# %%
titanic_passengers['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
titanic_passengers[(titanic_passengers['Age'] > 20) & (titanic_passengers['Sex'] == 'male')]
# Out:
#              Survived  Pclass                           Name   Sex   Age  \
# PassengerId
# 1                   0       3        Braund, Mr. Owen Harris  male  22.0
# 5                   0       3       Allen, Mr. William Henry  male  35.0
# 7                   0       1        McCarthy, Mr. Timothy J  male  54.0
# 14                  0       3    Andersson, Mr. Anders Johan  male  39.0
# 21                  0       2           Fynney, Mr. Joseph J  male  35.0
# ...               ...     ...                            ...   ...   ...
# 884                 0       2  Banfield, Mr. Frederick James  male  28.0
# 885                 0       3         Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2          Montvila, Rev. Juozas  male  27.0
# 890                 1       1          Behr, Mr. Karl Howell  male  26.0
# 891                 0       3            Dooley, Mr. Patrick  male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 5                0      0            373450   8.0500   NaN        S
# 7                0      0             17463  51.8625   E46        S
# 14               1      5            347082  31.2750   NaN        S
# 21               0      0            239865  26.0000   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 884              0      0  C.A./SOTON 34068  10.5000   NaN        S
# 885              0      0   SOTON/OQ 392076   7.0500   NaN        S
# 887              0      0            211536  13.0000   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [351 rows x 11 columns]

# %%
titanic_passengers['Total_number'] = titanic_passengers['SibSp'] + titanic_passengers['Parch']

# %%
titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Total_number
# PassengerId
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# 5                       0

# %%
titanic_passengers = titanic_passengers.drop(columns=['SibSp', 'Parch'])

# %%
titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0
# 3                                       Heikkinen, Miss. Laina   1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0
# 5                                     Allen, Mr. William Henry   0  35.0
#
#                        Ticket     Fare Cabin Embarked  Total_number
# PassengerId
# 1                   A/5 21171   7.2500   NaN        S             1
# 2                    PC 17599  71.2833   C85        C             1
# 3            STON/O2. 3101282   7.9250   NaN        S             0
# 4                      113803  53.1000  C123        S             1
# 5                      373450   8.0500   NaN        S             0

# %%
titanic_passengers.loc[titanic_passengers['Sex'] == 'male', 'Sex'] = 0
titanic_passengers.loc[titanic_passengers['Sex'] == 'female', 'Sex'] = 1

# %%
titanic_passengers.loc[1, 'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
import numpy as np
import pandas as pd

# %%
titanic_passengers = pd.read_csv('train.csv', index_col='PassengerId')

# %%
sex = titanic_passengers['Sex']
sex = (sex == 'male').astype(int)
titanic_passengers['Sex'] = sex

titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
embarked = titanic_passengers['Embarked']

embarked_dict = {
    'S': 0,
    'C': 1,
    'Q': 2
}

embarked = embarked.map(embarked_dict)
titanic_passengers['Embarked'] = embarked
titanic_passengers.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN       0.0
# 2                1      0          PC 17599  71.2833   C85       1.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN       0.0
# 4                1      0            113803  53.1000  C123       0.0
# 5                0      0            373450   8.0500   NaN       0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(titanic_passengers['Age'], titanic_passengers['Fare'], c=titanic_passengers['Survived'])

plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
import seaborn as sns

# %%
sns.pairplot(titanic_passengers, hue="Survived")

# %%
titanic_passengers.corr()
# Out:
# <ipython-input-46-9fe8e8e182d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic_passengers.corr()
#           Survived    Pclass  Sex       Age     SibSp     Parch      Fare  \
# Survived  1.000000 -0.338481  NaN -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000  NaN -0.369226  0.083081  0.018443 -0.549500
# Sex            NaN       NaN  NaN       NaN       NaN       NaN       NaN
# Age      -0.077221 -0.369226  NaN  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081  NaN -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443  NaN -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  NaN  0.096067  0.159651  0.216225  1.000000
# Embarked       NaN       NaN  NaN       NaN       NaN       NaN       NaN
#
#           Embarked
# Survived       NaN
# Pclass         NaN
# Sex            NaN
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Fare           NaN
# Embarked       NaN

# %%
sns.heatmap(titanic_passengers.corr(), annot=True)
# Out:
# <ipython-input-51-ad91f7305dbb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic_passengers.corr(), annot=True)
# <Axes: >

# %%
sns.countplot(titanic_passengers['Pclass'], hue=titanic_passengers["Survived"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-7f3804c46942> in <cell line: 1>()
# ----> 1 sns.countplot(titanic_passengers['Pclass'], hue=titanic_passengers["Survived"])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2629
# -> 2630     p = _CategoricalAggPlotter(
#    2631         data=data,
#    2632         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ---> 66         super().__init__(data=data, variables=variables)
#      67
#      68         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     671         if x is None and y is None:
#     672             self.input_format = "wide"
# --> 673             frame, names = self._assign_variables_wideform(data, **variables)
#     674         else:
#     675             # When dealing with long-form input, use the newer PlotData
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in _assign_variables_wideform(self, data, **kwargs)
#     721             err = f"The following variable{s} cannot be assigned with wide-form data: "
#     722             err += ", ".join(f"`{v}`" for v in assigned)
# --> 723             raise ValueError(err)
#     724
#     725         # Determine if the data object actually has any data in it
#
# ValueError: The following variable cannot be assigned with wide-form data: `hue`

# %%
sns.countplot(x='Pclass', hue='Survived', data=titanic_passengers)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
